# %% [markdown]
# Super important information

# %% [markdown]
# Test

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2
# Load an image
# img_path = r"C:\Users\hanna\Skola\Projektkurs\Projektkurs_Images\Test_Set\6_MariaCallas_31_f.jpg"
img_path = r"C:\Users\hanna\Skola\Projektkurs\hanna1.JPG"
# "C:\Users\hanna\Skola\Projektkurs\hanna1.JPG"
img = cv2.imread(img_path)
if img is None:
    print("Failed to load image. Check the file path.")
else:
    print("Image loaded successfully.")
# Analyze the image for age and gender
objs = DeepFace.analyze(img, actions=['age', 'gender'])
embedding = DeepFace.represent(img_path=img_path, model_name="ArcFace")

# Access the dominant gender from the analysis
dominant_gender = objs[0]['dominant_gender']
age=objs[1]['age']

# Print the result
print(f"Dominant Gender: {dominant_gender}")
print(f"Age: {age}")

# Show the image
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct display in matplotlib
plt.axis('off')  # Hide axes for cleaner display
plt.show()
# Out:
# Image loaded successfully.
# ...
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  2.95it/s]
# Dominant Gender: Woman
# Age: 25

# %%
from deepface import DeepFace
import cv2

# Load an image
img_path = r"C:\Users\hanna\Skola\Projektkurs\Projektkurs_Images\Test_Set\6_MariaCallas_31_f.jpg"
img = cv2.imread(img_path)

if img is None:
    print("Failed to load image. Check the file path.")
else:
    print("Image loaded successfully.")

# Extract the feature vector using the desired model
embedding = DeepFace.represent(img_path=img_path, model_name="ArcFace")

# Print the feature vector
print("Feature Vector (Embedding):")
print(embedding)
# Out:
# Image loaded successfully.
# 24-11-18 13:02:05 - arcface_weights.h5 will be downloaded to C:\Users\hanna\.deepface/weights\arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: C:\Users\hanna\.deepface\weights\arcface_weights.h5
# 100%|██████████| 137M/137M [00:04<00:00, 27.5MB/s]
# Feature Vector (Embedding):
# ...

# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2
import os

# Define the folder containing images
folder_path = r"C:\Users\hanna\Skola\Projektkurs\Projektkurs_Images\Test_Set"

# Create a list to store results
results = []

# Iterate through each file in the folder
for filename in os.listdir(folder_path):
    file_path = os.path.join(folder_path, filename)
    
    # Check if the file is an image
    if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.gif')):
        # Load the image
        img = cv2.imread(file_path)
        if img is None:
            print(f"Failed to load image: {filename}")
            continue
        
        print(f"Processing image: {filename}")
        
        try:
            # Analyze the image for age and gender
            objs = DeepFace.analyze(img, actions=['age', 'gender'])
            
            # Extract the embedding
            embedding = DeepFace.represent(img_path=file_path, model_name="ArcFace")
            
            # Access age and gender analysis
            age = objs[0]['age']
            dominant_gender = objs[0]['dominant_gender']
            
            # Store the results
            results.append({
                "filename": filename,
                "age": age,
                "dominant_gender": dominant_gender,
                "embedding": embedding
            })
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# Print the results
for result in results:
    print(f"Filename: {result['filename']}, Age: {result['age']}, Gender: {result['dominant_gender']}")

# Optional: Display one of the processed images
if results:
    img_to_display = results[0]['filename']
    img_path = os.path.join(folder_path, img_to_display)
    img = cv2.imread(img_path)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.title(f"Age: {results[0]['age']}, Gender: {results[0]['dominant_gender']}")
    plt.axis('off')
    plt.show()
# Out:
# Processing image: 10_MariaCallas_28_f.jpg
# Error processing 10_MariaCallas_28_f.jpg: Face could not be detected in numpy array.Please confirm that the picture is a face photo or consider to set enforce_detection param to False.
# Processing image: 11_MariaCallas_39_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  3.05it/s]
# Processing image: 12_MariaCallas_37_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  3.45it/s]
# Processing image: 13_MariaCallas_53_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  3.73it/s]
# Processing image: 14_MariaCallas_32_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  3.26it/s]
# Processing image: 15_MariaCallas_42_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  3.95it/s]
# Processing image: 16_MariaCallas_34_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  3.73it/s]
# Processing image: 17_MariaCallas_33_f.jpg
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  4.01it/s]
# ...
